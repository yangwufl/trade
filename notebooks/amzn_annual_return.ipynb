# %%
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("talk")

# %%
amzn_mo_pricing = yf.download(
    tickers="AMZN",
    start=None,
    end="2021-05-05",
    interval="1mo",
)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
amzn_mo_pricing
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1997-06-01     1.510417     1.708333     1.375000     1.541667     1.541667
# 1997-07-01     1.541667     2.572917     1.510417     2.395833     2.395833
# 1997-08-01     2.343750     2.416667     1.937500     2.338542     2.338542
# 1997-09-01     2.343750     4.812500     2.312500     4.338542     4.338542
# 1997-10-01     4.437500     5.500000     3.520833     5.083333     5.083333
# ...                 ...          ...          ...          ...          ...
# 2021-01-01  3270.000000  3363.889893  3086.000000  3206.199951  3206.199951
# 2021-02-01  3242.360107  3434.000000  3036.699951  3092.929932  3092.929932
# 2021-03-01  3127.889893  3182.000000  2881.000000  3094.080078  3094.080078
# 2021-04-01  3117.939941  3554.000000  3115.550049  3467.419922  3467.419922
# 2021-05-01  3484.729980  3486.649902  3127.370117  3223.070068  3223.070068
#
#                  Volume
# Date
# ...

# %%
amzn_mo_pricing["Date"] = amzn_mo_pricing.index
amzn_mo_pricing["Month"] = amzn_mo_pricing.Date.apply(lambda d: d.month)
amzn_mo_pricing = amzn_mo_pricing[amzn_mo_pricing.Month==12].dropna(how="any")

# %%
amzn_mo_pricing.Close.plot(figsize=(20,5));

# %%
amzn_mo_pricing["Close_Prev"] = amzn_mo_pricing.Close.shift(1)
amzn_mo_pricing["Return"] = amzn_mo_pricing.Close/amzn_mo_pricing.Close_Prev - 1.0
amzn_mo_pricing
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1997-12-01     4.239583     5.041667     4.135417     5.020833     5.020833
# 1998-12-01    30.916668    60.312500    30.333332    53.541668    53.541668
# 1999-12-01    87.250000   113.000000    76.000000    76.125000    76.125000
# 2000-12-01    24.937500    27.625000    14.875000    15.562500    15.562500
# 2001-12-01    11.020000    12.800000     9.510000    10.820000    10.820000
# 2002-12-01    24.150000    25.000000    18.430000    18.889999    18.889999
# 2003-12-01    54.400002    54.939999    47.000000    52.619999    52.619999
# 2004-12-01    40.000000    45.680000    37.990002    44.290001    44.290001
# 2005-12-01    48.880001    50.000000    47.139999    47.150002    47.150002
# 2006-12-01    40.259998    40.639999    37.700001    39.459999    39.459999
# 2007-12-01    90.029999    95.940002    83.860001    92.639999    92.639999
# ...

# %%
amzn_mo_pricing.Return.hist(bins=10, histtype="step", grid=False, figsize=(20,5));

# %%
amzn_mo_pricing.Return.mean(), amzn_mo_pricing.Return.median()
# Out:
# (0.7837121204454026, 0.33809094768851256)

# %%
amzn_mo_pricing.tail(10)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2011-12-01   191.850006   199.660004   166.970001   173.100006   173.100006
# 2012-12-01   252.539993   263.109985   242.750000   250.869995   250.869995
# 2013-12-01   399.000000   405.630005   379.500000   398.790009   398.790009
# 2014-12-01   338.119995   340.640015   293.029999   310.350006   310.350006
# 2015-12-01   673.750000   696.440002   635.270020   675.890015   675.890015
# 2016-12-01   752.409973   782.460022   736.700012   749.869995   749.869995
# 2017-12-01  1172.050049  1194.780029  1124.739990  1169.469971  1169.469971
# 2018-12-01  1769.459961  1778.339966  1307.000000  1501.969971  1501.969971
# 2019-12-01  1804.400024  1901.400024  1735.000000  1847.839966  1847.839966
# 2020-12-01  3188.500000  3350.649902  3072.820068  3256.929932  3256.929932
#
#                  Volume       Date  Month   Close_Prev    Return
# Date
# ...

# %%
amzn_mo_pricing.tail(10).Return.plot(figsize=(20,5));

# %%
amzn_mo_pricing.tail(10).Return.mean(), amzn_mo_pricing.tail(10).Return.median()
# Out:
# (0.3902807570832089, 0.36679731457742426)

# %%
amzn_mo_pricing.tail(20).Return.mean(), amzn_mo_pricing.tail(20).Return.median()
# Out:
# (0.4367627039915016, 0.3112038910458924)

# %%
amzn_mo_pricing.tail(30).Return.mean(), amzn_mo_pricing.tail(30).Return.median()
# Out:
# (0.7837121204454026, 0.33809094768851256)

# %%
3200*150
# Out:
# 480000

# %%
3200*150*(1.39**4)
# Out:
# 1791844.9967999996

# %%
aapl_mo_pricing = yf.download(
    tickers="AAPL",
    start=None,
    end="2021-05-05",
    interval="1mo",
)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
aapl_mo_pricing["Date"] = aapl_mo_pricing.index
aapl_mo_pricing["Month"] = aapl_mo_pricing.Date.apply(lambda d: d.month)
aapl_mo_pricing = aapl_mo_pricing[aapl_mo_pricing.Month==12].dropna(how="any")

# %%
aapl_mo_pricing.Close.plot(figsize=(20,5));

# %%
aapl_mo_pricing["Close_Prev"] = aapl_mo_pricing.Close.shift(1)
aapl_mo_pricing["Return"] = aapl_mo_pricing.Close/aapl_mo_pricing.Close_Prev - 1.0
aapl_mo_pricing
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1985-12-01    0.089844    0.102121    0.085938    0.098214    0.077096
# 1986-12-01    0.178571    0.195871    0.174665    0.180804    0.141928
# 1987-12-01    0.299107    0.390625    0.265625    0.375000    0.295841
# 1988-12-01    0.337054    0.375000    0.334821    0.359375    0.285925
# 1989-12-01    0.397321    0.408482    0.290179    0.314732    0.252865
# 1990-12-01    0.332589    0.404018    0.330357    0.383929    0.312291
# 1991-12-01    0.453125    0.517857    0.433036    0.503348    0.413258
# 1992-12-01    0.511161    0.546875    0.486607    0.533482    0.441821
# 1993-12-01    0.285714    0.290179    0.236607    0.261161    0.218954
# 1994-12-01    0.330357    0.356027    0.310268    0.348214    0.296050
# 1995-12-01    0.339286    0.358259    0.282366    0.284598    0.244727
# 1996-12-01    0.215402    0.227679    0.185268    0.186384    0.160272
# ...

# %%
aapl_mo_pricing.tail(10).Return.mean()
# Out:
# 0.31172879363453304

# %%
aapl_mo_pricing.tail(20).Return.mean()
# Out:
# 0.4963405051745878

# %%
aapl_mo_pricing.tail(30).Return.mean()
# Out:
# 0.4047131540978745
